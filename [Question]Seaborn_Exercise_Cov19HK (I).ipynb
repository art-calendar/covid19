# %% [markdown]
# # **Seaborn**

# %% [markdown]
# ## **Importing Libraries**

# %% [markdown]
# ## **Getting Data**

# %% [markdown]
# **Department of Heath - GovHK** provides a link to retrieve historical data on COVID-19 cases in HK.
#
# You can download the data from the website (https://www.chp.gov.hk/files/misc/enhanced_sur_covid_19_eng.csv).

# %%
# Create the url that links to a csv file containing the cases of covid-19

# %%
# Read the content of the server’s response
# Out:
# 'Case no.,Report date,Date of onset,Gender,Age,Name of hospital admitted,Hospitalised/Discharged/Deceased,HK/Non-HK resident,Case classification*,Confirmed/probable\r\n1,23/01/2020,21/01/2020,M,39,,Discharged,Non-HK resident,Imported case,Confirmed\r\n2,23/01/2020,18/01/2020,M,56,,Discharged,HK resident,Imported case,Confirmed\r\n3,24/01/2020,20/01/2020,F,62,,Discharged,Non-HK resident,Imported case,Confirmed\r\n4,24/01/2020,23/01/2020,F,62,,Discharged,Non-HK resident,Imported case,Confirmed\r\n5,24/01/2020,23/01/2020,M,63,,Discharged,Non-HK resident,Imported case,Confirmed\r\n6,26/01/2020,21/01/2020,M,47,,Discharged,HK resident,Imported case,Confirmed\r\n7,26/01/2020,21/01/2020,F,68,,Discharged,HK resident,Imported case,Confirmed\r\n8,26/01/2020,25/01/2020,M,64,,Discharged,Non-HK resident,Imported case,Confirmed\r\n9,29/01/2020,25/01/2020,F,73,,Discharged,Non-HK resident,Imported case,Confirmed\r\n10,29/01/2020,25/01/2020,M,72,,Discharged,Non-HK resident,Imported case,Confirmed\r\n1
# ...

# %%
# Read and write strings as files
# hint: StringIO

# %%
# load the csv file
# Out:
#       Case no.  ... Confirmed/probable
# 0            1  ...          Confirmed
# 1            2  ...          Confirmed
# 2            3  ...          Confirmed
# 3            4  ...          Confirmed
# 4            5  ...          Confirmed
# ...        ...  ...                ...
# 8148      8149  ...          Confirmed
# 8149      8150  ...          Confirmed
# 8150      8151  ...          Confirmed
# 8151      8152  ...          Confirmed
# 8152      8153  ...          Confirmed
#
# [8153 rows x 10 columns]

# %%
# return the last 100 rows
# Out:
#       Case no.  ... Confirmed/probable
# 8053      8054  ...          Confirmed
# 8054      8055  ...          Confirmed
# 8055      8056  ...          Confirmed
# 8056      8057  ...          Confirmed
# 8057      8058  ...          Confirmed
# ...        ...  ...                ...
# 8148      8149  ...          Confirmed
# 8149      8150  ...          Confirmed
# 8150      8151  ...          Confirmed
# 8151      8152  ...          Confirmed
# 8152      8153  ...          Confirmed
#
# [100 rows x 10 columns]

# %%
# print information about the DataFrame
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8153 entries, 0 to 8152
# Data columns (total 10 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Case no.                          8153 non-null   int64
#  1   Report date                       8153 non-null   object
#  2   Date of onset                     8153 non-null   object
#  3   Gender                            8153 non-null   object
#  4   Age                               8153 non-null   int64
#  5   Name of hospital admitted         0 non-null      float64
#  6   Hospitalised/Discharged/Deceased  8152 non-null   object
#  7   HK/Non-HK resident                8153 non-null   object
#  8   Case classification*              8153 non-null   object
#  9   Confirmed/probable                8153 non-null   object
# dtypes: float64(1), int64(2), object(7)
# memory usage: 637.1+ KB

# %% [markdown]
# ## **Basic Analysis**

# %% [markdown]
# **Case classification***

# %%
# Out:
# Epidemiologically linked with local case             4052
# Local case                                           2135
# Imported case                                        1760
# Possibly local case                                   103
# Epidemiologically linked with possibly local case      62
# Epidemiologically linked with imported case            41
# Name: Case classification*, dtype: int64

# %% [markdown]
# **Hospitalised / Discharged / Deceased**

# %%
# Out:
# Discharged           6837
# Hospitalised         1081
# Deceased              129
# To be provided         74
# No admission           30
# Pending admission       1
# Name: Hospitalised/Discharged/Deceased, dtype: int64

# %%
# Out:
#                                      Case no.  ...  Name of hospital admitted
# Hospitalised/Discharged/Deceased               ...
# Deceased                          3381.170543  ...                        NaN
# Discharged                        3544.903905  ...                        NaN
# Hospitalised                      7284.695652  ...                        NaN
# No admission                      2545.466667  ...                        NaN
# Pending admission                 7982.000000  ...                        NaN
# To be provided                    8116.500000  ...                        NaN
#
# [6 rows x 3 columns]

# %% [markdown]
# **Case no.**

# %%
# Out:
# 8153

# %% [markdown]
# **Gender**

# %% [markdown]
# **Age**

# %%
# Out:
# 45.33067582484975

# %% [markdown]
# ## **Advanced Analysis**

# %%
# "Case no." >200 and "Age" <40
# Out:
#       Case no.  ... Confirmed/probable
# 200        201  ...          Confirmed
# 201        202  ...          Confirmed
# 202        203  ...          Confirmed
# 204        205  ...          Confirmed
# 206        207  ...          Confirmed
# ...        ...  ...                ...
# 8144      8145  ...          Confirmed
# 8145      8146  ...          Confirmed
# 8146      8147  ...          Confirmed
# 8149      8150  ...          Confirmed
# 8151      8152  ...          Confirmed
#
# [3206 rows x 10 columns]

# %%
# "Case no." >200 and "Age" <40 & "Case classification" = Imported

# %%
# report date: 27Mar2020
